# %% [markdown]
# <a href="https://colab.research.google.com/github/cjimenez275/Simulacion_Fisica/blob/main/10_Analitica.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Analítica de datos

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %%
paises = pd.read_excel("datos_paises.xlsx", index_col=0)
paises.head(3)
# Out:
#                          continente        km2  poblacion_miles
# pais
# China                          Asia  9600000.0          1409517
# India                          Asia  3287263.0          1339180
# United States of America    America  9833517.0           324460

# %%
paises[paises["km2"]<50]
# Out:
#                                  continente   km2  poblacion_miles
# pais
# China, Macao SAR                       Asia  30.0              623
# Sint Maarten (Dutch part)           America  34.0               40
# Monaco                               Europa   2.0               39
# Gibraltar                            Europa   6.0               35
# Bonaire, Sint Eustatius and Saba    America   1.0               25
# Nauru                               Oceania  21.0               11
# Tuvalu                              Oceania  26.0               11
# Holy See                             Europa   1.0                1
# Tokelau                             Oceania  12.0                1

# %% [markdown]
# Podemos unir condiciones con simbolos lógicos
#
# & = y ******** | = o ********** ~ = not

# %%
paises[(paises["km2"] < 80) & ~(paises["continente"] == "Europa")]
# Out:
#                                  continente   km2  poblacion_miles
# pais
# China, Macao SAR                       Asia  30.0              623
# Bermuda                             America  53.0               61
# Sint Maarten (Dutch part)           America  34.0               40
# Bonaire, Sint Eustatius and Saba    America   1.0               25
# Nauru                               Oceania  21.0               11
# Tuvalu                              Oceania  26.0               11
# Tokelau                             Oceania  12.0                1

# %% [markdown]
# # Gráficos con SeaBorn

# %%
sns.get_dataset_names();

# %%
pinguinos = sns.load_dataset("penguins")

# %%
pinguinos.columns = ["especie", "isla", "longitud_pico",
                     "profundidad_pico", "longitud_aleta", "masa", "sexo"]
pinguinos.head(2)
# Out:
#   especie       isla  longitud_pico  profundidad_pico  longitud_aleta    masa  \
# 0  Adelie  Torgersen           39.1              18.7           181.0  3750.0
# 1  Adelie  Torgersen           39.5              17.4           186.0  3800.0
#
#      sexo
# 0    Male
# 1  Female

# %%
pinguinos.describe()
# Out:
#        longitud_pico  profundidad_pico  longitud_aleta         masa
# count     342.000000        342.000000      342.000000   342.000000
# mean       43.921930         17.151170      200.915205  4201.754386
# std         5.459584          1.974793       14.061714   801.954536
# min        32.100000         13.100000      172.000000  2700.000000
# 25%        39.225000         15.600000      190.000000  3550.000000
# 50%        44.450000         17.300000      197.000000  4050.000000
# 75%        48.500000         18.700000      213.000000  4750.000000
# max        59.600000         21.500000      231.000000  6300.000000

# %%
sns.relplot(data=pinguinos,
           x="longitud_pico",
           y="longitud_aleta", height=7)
plt.show()

# %%
sns.relplot(data=pinguinos,
           x="longitud_pico",
           y="longitud_aleta",
           hue="masa")
plt.show()

# %%
sns.relplot(data=pinguinos,
           x="longitud_pico",
           y="longitud_aleta",
           hue="especie")
plt.show()

# %%
sns.relplot(data=pinguinos,
           x="longitud_pico",
           y="longitud_aleta",
           hue="sexo")
plt.show()

# %%
sns.relplot(data=pinguinos,
           x="longitud_pico",
           y="longitud_aleta",
           hue="especie",
            row="sexo",
            size="masa",
            sizes=(100, 500),
           style="sexo")
plt.show()

# %%
sns.violinplot(data=pinguinos, x="longitud_aleta", y="isla")
plt.show()

# %%
sns.catplot(data=pinguinos, x="isla", y="longitud_aleta", kind='strip', hue='sexo')
plt.show()

# %%
sns.displot(data=pinguinos, x="longitud_pico", hue="especie", multiple="stack")
plt.show()
